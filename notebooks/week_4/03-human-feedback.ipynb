# %%
from langsmith import Client

# %%
client = Client()
RUN_ID = "019c377a-8845-7253-944b-f9bade107b21"

# %%
client.create_feedback(
    run_id=RUN_ID,
    key="user_feedback",
    score=0,
    comment="Human feedback",
    value="This is a test feedback from user 1",
    feedback_source_type="api",
    metadata={"user_id": "1234567890"}
)
# Out:
# Feedback(id=UUID('019c37a5-f95b-7e31-b4a9-6663ef031cd5'), created_at=datetime.datetime(2026, 2, 7, 10, 29, 10, 108370, tzinfo=datetime.timezone.utc), modified_at=datetime.datetime(2026, 2, 7, 10, 29, 10, 108374, tzinfo=datetime.timezone.utc), run_id=UUID('019c377a-8845-7253-944b-f9bade107b21'), trace_id=None, key='user_feedback', score=0, value='This is a test feedback from user 1', comment='Human feedback', correction=None, feedback_source=FeedbackSourceBase(type='api', metadata={}, user_id=None, user_name=None), session_id=None, comparative_experiment_id=None, feedback_group_id=None, extra=None)
